# %% [markdown]
# 0.Intro
#
# 지하철과 함께 시민들의 발이 되어 주는 버스.
# 특히 제주도같이 지하철을 이용할 수 없는 곳에서는 더더욱 소중하죠.
# 하지만, 필요할 때 타지 못한다면 결국은 무용지물!
# 승객들이 버스를 효율적으로 이용할 수 있게 하려면 어떻게 운영해야 할까요?
#
# 버스 운행 시간 예측 프로젝트에 참여하신 데이커 여러분, 환영합니다. 🙌
# 한국처럼 대중교통이 잘 발달한 나라도 세계적으로 드물다고 하죠.
# 특히나 도서 지방은 지리적 특성상 지하철을 설치하기 어려워 버스 의존도가 내륙에 비하여 더 높은 것이 현실입니다.
#
# 다 함께 제주도의 버스 운행 시간을 예측해서 더 쾌적한 제주도를 만들어 볼까요?
#
# 물류/운송 프로젝트 초보자도 함께하는 데이콘 프로젝트 교육, go go!
#
# [프로젝트 배경]
#
# ![image.png](attachment:image.png)
#
# 2017년 한국은행 제주 본부에 따르면, 제주도 일부 지역은 교통 체증이 서울보다 심각하다고 합니다.
#
# 주민등록상 제주도 내 인구는 2019년 11월 기준 69만 명으로, 연평균 4% 대로 증가하고 있습니다.
# 외국인과 관광객까지 고려하면 상주 인구는 90만 명을 넘을 것으로 추정되는데요!
#
# 코로나 이후 외국인 관광객의 수요가 줄어들었다고는 하지만,
# 내국인 관광객과 거주자의 증가로 현재 제주도의 교통 체증은 심각한 문제로 떠오르고 있습니다.
#
# 그리고 이 제주도의 대표적인 대중교통 수단은 바로 버스인데요.
#
# 버스 운행 정보는 형태와 변수가 약간만 바뀌면, 물류 유통 및 운송 데이터 프로젝트로 확장이 가능한 중요한 데이터입니다.
#
# 제주도 버스의 운행 시간을 예측하는 이번 프로젝트를 통해, 물류/운송 프로젝트의 핵심을 파악해 보겠습니다.

# %% [markdown]
# 1.Pandas 불러오기
#
# [문제 1]
# pandas 라이브러리를 불러오기 위해서 아래 빈칸을 채워주세요.
# 단, pandas는 자주 사용하는 라이브러리이므로 축약어인 pd 로 불러와주세요.

# %%
import pandas as pd

# %% [markdown]
# 2.데이터 불러오기
#
# 데이터를 불러옴으로써 데이터의 모양과 대략적인 내용을 파악하고, 어떤 분석이 가능한지 확인하여 방향을 잡는 과정이 필요합니다.
#
# 이번 프로젝트의 데이터는 총 3가지이며 모두 csv 파일입니다.
#
#   1. train.csv: 데이터 분석 모델을 학습(train)하기 위해 사용하는 데이터
#   2. test.csv: 데이터 분석 모델을 통해 정답을 예측하기 위해 사용하는 데이터
#   3. sample_submission.csv: 예측한 정답 값을 기록하여 제출하기 위한 샘플 정답 파일
# 위에서 호출한 라이브러리를 활용하여 'train.csv' 파일을 불러와봅시다!

# %%
train = pd.read_csv('train.csv')
train

# %% [markdown]
# ![image.png](attachment:image.png)
#
# 3.데이터 불러오기 연습
#
# [문제 2]
# train 파일을 불러와봤으니 이제 test.csv, sample_submission.csv 파일도 불러와볼까요?
# 아래 빈칸을 채워주세요.

# %%
test = pd.read_csv('test.csv')
submission = pd.read_csv('sample_submission.csv')

# %% [markdown]
# 4.데이터 확인하기
#
# 위에서 sample_submission.csv를 submission 변수로 할당을 해주었습니다.
# submission 데이터를 확인해보겠습니다.

# %%
submission.head()

# %% [markdown]
# ![image.png](attachment:image.png)
#
# 5.CSV파일 저장하기
#
# csv파일을 불러오는 법도 알았으니, 저장하는 방법도 알아야겠죠?
# 불러온 데이터에서 어떠한 값도 변경되지 않았으나 연습을 위해서 저장해봅시다!

# %%
submission.to_csv('submission.csv', index=False)
