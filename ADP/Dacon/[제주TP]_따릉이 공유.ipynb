# %% [markdown]
# ## 따릉이 데이터를 활용한 데이터 분석

# %% [markdown]
# - 각 날짜의 1시간 전의 기상상황을 가지고 1시간 후의 따릉이 대여수를 예측해보세요.

# %% [markdown]
# ## 1. 라이브러리 및 데이터
# ## Library & Data

# %%
import pandas as pd #판다스 패키지 불러오기
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor #랜덤 포레스트 불러오기

# %%
# 데이터 불러오기
train = pd.read_csv('data/train.csv')# 모델 학습 파일
test = pd.read_csv('data/test.csv')# 모델 시험지 파일
submission = pd.read_csv('data/submission.csv')#답안지 파일
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 # 데이터 불러오기
# ----> 2 train = pd.read_csv('data/train.csv')# 모델 학습 파일
#       3 test = pd.read_csv('data/test.csv')# 모델 시험지 파일
#       4 submission = pd.read_csv('data/submission.csv')#답안지 파일
#
# File c:\Users\user\AppData\Local\anaconda3\envs\py310\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\user\AppData\Local\anaconda3\envs\py310\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\user\AppData\Local\anaconda3\envs\py310\lib\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\user\AppData\Local\anaconda3\envs\py310\lib\site-packages\pandas\io\parsers\readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File c:\Users\user\AppData\Local\anaconda3\envs\py310\lib\site-packages\pandas\io\parsers\readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\user\AppData\Local\anaconda3\envs\py310\lib\site-packages\pandas\io\parsers\readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File c:\Users\user\AppData\Local\anaconda3\envs\py310\lib\site-packages\pandas\io\common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/train.csv'

# %% [markdown]
# ## 2. 탐색적 자료분석
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### pd.DataFrame.head()
#  - 데이터 프레임의 위에서 부터 n개 행을 보여주는 함수
#  - n의 기본 값(default 값)은 5

# %%
train.head()
# Out:
#    id  hour  hour_bef_temperature  hour_bef_precipitation  hour_bef_windspeed  \
# 0   3    20                  16.3                     1.0                 1.5
# 1   6    13                  20.1                     0.0                 1.4
# 2   7     6                  13.9                     0.0                 0.7
# 3   8    23                   8.1                     0.0                 2.7
# 4   9    18                  29.5                     0.0                 4.8
#
#    hour_bef_humidity  hour_bef_visibility  hour_bef_ozone  hour_bef_pm10  \
# 0               89.0                576.0           0.027           76.0
# 1               48.0                916.0           0.042           73.0
# 2               79.0               1382.0           0.033           32.0
# 3               54.0                946.0           0.040           75.0
# 4                7.0               2000.0           0.057           27.0
#
#    hour_bef_pm2.5  count
# 0            33.0   49.0
# 1            40.0  159.0
# 2            19.0   26.0
# 3            64.0   57.0
# 4            11.0  431.0

# %% [markdown]
# + id : 날짜와 시간별 id
# + hour_bef_temperature : 1시간 전 기온
# + hour_bef_precipitation : 1시간 전 비 정보, 비가 오지 않았으면 0, 비가 오면 1
# + hour_bef_windspeed : 1시간 전 풍속(평균)
# + hour_bef_humidity : 1시간 전 습도
# + hour_bef_visibility : 1시간 전 시정(視程), 시계(視界)(특정 기상 상태에 따른 가시성을 의미)
# + hour_bef_ozone : 1시간 전 오존
# + hour_bef_pm10 : 1시간 전 미세먼지(머리카락 굵기의 1/5에서 1/7 크기의 미세먼지)
# + hour_bef_pm2.5 : 1시간 전 미세먼지(머리카락 굵기의 1/20에서 1/30 크기의 미세먼지)
# + count : 시간에 따른 따릉이 대여 수

# %%
test.head()
# Out:
#    id  hour  hour_bef_temperature  hour_bef_precipitation  hour_bef_windspeed  \
# 0   0     7                  20.7                     0.0                 1.3
# 1   1    17                  30.0                     0.0                 5.4
# 2   2    13                  19.0                     1.0                 2.1
# 3   4     6                  22.5                     0.0                 2.5
# 4   5    22                  14.6                     1.0                 3.4
#
#    hour_bef_humidity  hour_bef_visibility  hour_bef_ozone  hour_bef_pm10  \
# 0               62.0                954.0           0.041           44.0
# 1               33.0               1590.0           0.061           49.0
# 2               95.0                193.0           0.020           36.0
# 3               60.0               1185.0           0.027           52.0
# 4               93.0                218.0           0.041           18.0
#
#    hour_bef_pm2.5
# 0            27.0
# 1            36.0
# 2            28.0
# 3            38.0
# 4            15.0

# %%
submission.head()
# Out:
#    id  count
# 0   0    NaN
# 1   1    NaN
# 2   2    NaN
# 3   4    NaN
# 4   5    NaN

# %% [markdown]
# ### pd.DataFrame.tail()
#  - 데이터 프레임의 아래에서 부터 n개 행을 보여주는 함수
#  - n의 기본 값(default 값)은 5

# %%
train.tail()
# Out:
#         id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 1454  2174     4                  16.8                     0.0
# 1455  2175     3                  10.8                     0.0
# 1456  2176     5                  18.3                     0.0
# 1457  2178    21                  20.7                     0.0
# 1458  2179    17                  21.1                     0.0
#
#       hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 1454                 1.6               53.0               2000.0
# 1455                 3.8               45.0               2000.0
# 1456                 1.9               54.0               2000.0
# 1457                 3.7               37.0               1395.0
# 1458                 3.1               47.0               1973.0
#
#       hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5  count
# 1454           0.031           37.0            27.0   21.0
# 1455           0.039           34.0            19.0   20.0
# 1456           0.009           30.0            21.0   22.0
# 1457           0.082           71.0            36.0  216.0
# 1458           0.046           38.0            17.0  170.0

# %% [markdown]
# ### pd.DataFrame.shape
#  - 데이터 프레임의 행의 개수와 열의 개수가 저장되어 있는 속성(attribute)

# %%
train.shape
# Out:
# (1459, 11)

# %%
test.shape
# Out:
# (715, 10)

# %%
submission.shape
# Out:
# (715, 2)

# %% [markdown]
# ### pd.DataFrame.info()
# - 데이터셋의 column별 정보를 알려주는 함수
# - 비어 있지 않은 값은 (non-null)은 몇개인지?
# - column의 type은 무엇인지?
#  - type의 종류 : int(정수), float(실수), object(문자열), 등등 (date, ...)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      1459 non-null   int64
#  1   hour                    1459 non-null   int64
#  2   hour_bef_temperature    1457 non-null   float64
#  3   hour_bef_precipitation  1457 non-null   float64
#  4   hour_bef_windspeed      1450 non-null   float64
#  5   hour_bef_humidity       1457 non-null   float64
#  6   hour_bef_visibility     1457 non-null   float64
#  7   hour_bef_ozone          1383 non-null   float64
#  8   hour_bef_pm10           1369 non-null   float64
#  9   hour_bef_pm2.5          1342 non-null   float64
#  10  count                   1459 non-null   float64
# dtypes: float64(9), int64(2)
# memory usage: 125.5 KB

# %% [markdown]
# ### pd.DataFrame.describe()
# - 숫자형 (int, float) column들의 기술 통계량을 보여주는 함수
#
# - 기술통계량이란?
#  - 해당 column을 대표할 수 있는 통계값들을 의미
#
#
# - 기술통계량 종류
#  - count: 해당 column에서 비어 있지 않은 값의 개수
#  - mean: 평균
#  - std: 표준편차
#  - min: 최솟값 (이상치 포함)
#  - 25% (Q1): 전체 데이터를 순서대로 정렬했을 때, 아래에서 부터 1/4번째 지점에 있는 값
#  - 50% (Q2): 중앙값 (전체 데이터를 순서대로 정렬했을 때, 아래에서 부터 2/4번째 지점에 있는 값)
#  - 75% (Q3): 전체 데이터를 순서대로 정렬했을 때, 아래에서 부터 3/4번째 지점에 있는 값
#  - max: 최댓값 (이상치 포함)
#
#
#
# - 이상치: 울타리 밖에 있는 부분을 이상치라고 정의함
#    - 아래쪽 울타리: $Q_1$ - $1.5 * IQR$
#    - 위쪽 울타리: $Q_3$ + $1.5 * IQR$
#    - $IQR$ = $Q_3 - Q_1$
#
#
# <img src="https://miro.medium.com/max/10125/1*NRlqiZGQdsIyAu0KzP7LaQ.png" width="700" height="500">

# %%
train.describe()
# Out:
#                 id         hour  hour_bef_temperature  hour_bef_precipitation  \
# count  1459.000000  1459.000000           1457.000000             1457.000000
# mean   1105.914325    11.493489             16.717433                0.031572
# std     631.338681     6.922790              5.239150                0.174917
# min       3.000000     0.000000              3.100000                0.000000
# 25%     555.500000     5.500000             12.800000                0.000000
# 50%    1115.000000    11.000000             16.600000                0.000000
# 75%    1651.000000    17.500000             20.100000                0.000000
# max    2179.000000    23.000000             30.000000                1.000000
#
#        hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# count         1450.000000        1457.000000          1457.000000
# mean             2.479034          52.231297          1405.216884
# std              1.378265          20.370387           583.131708
# min              0.000000           7.000000            78.000000
# 25%              1.400000          36.000000           879.000000
# 50%              2.300000          51.000000          1577.000000
# 75%              3.400000          69.000000          1994.000000
# max              8.000000          99.000000          2000.000000
#
#        hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5        count
# count     1383.000000    1369.000000     1342.000000  1459.000000
# mean         0.039149      57.168736       30.327124   108.563400
# std          0.019509      31.771019       14.713252    82.631733
# min          0.003000       9.000000        8.000000     1.000000
# 25%          0.025500      36.000000       20.000000    37.000000
# 50%          0.039000      51.000000       26.000000    96.000000
# 75%          0.052000      69.000000       37.000000   150.000000
# max          0.125000     269.000000       90.000000   431.000000

# %% [markdown]
# ### pd.DataFrame.groupby()
#  - 집단에 대한 통계량 확인
#
# <img src="https://s3.amazonaws.com/files.dezyre.com/images/Tutorials/Split+Apply+Combine+Strategy.png" width="700" height="500">

# %%
train[['hour','count']].groupby('hour').mean()
# Out:
#            count
# hour
# 0      71.766667
# 1      47.606557
# 2      31.409836
# 3      21.377049
# 4      13.524590
# 5      13.114754
# 6      24.557377
# 7      62.360656
# 8     136.688525
# 9      93.540984
# 10     78.803279
# 11     88.327869
# 12    111.901639
# 13    120.050000
# 14    134.590164
# 15    152.967213
# 16    169.100000
# 17    187.133333
# 18    262.163934
# 19    201.606557
# 20    164.868852
# 21    168.816667
# 22    148.245902
# 23    103.852459

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### plt.plot()의 스타일
#
# 색깔
#
# |문자열|약자|
# |----|-----|
# |blue|b|
# |green|g|
# |red|r|
# |cyan|c|
# |magenta|m|
# |yellow|y|
# |black|k|
# |white|w|
#
# 마커
#
# |마커|의미|
# |----|----|
# |.|점|
# |o|원|
# |v|역삼각형|
# |^|삼각형|
# |s|사각형|
# |*|별|
# |x|엑스|
# |d|다이아몬드|
#
# 선
#
# |문자열|의미|
# |-----|-----|
# | - | 실선|
# |-- | 끊어진 실선|
# | -.| 점+실선|
# |:|점선|

# %%
import matplotlib.pyplot as plt

# %%
plt.plot('hour', 'count', '*', data = train)

# %%
train.columns
# Out:
# Index(['id', 'hour', 'hour_bef_temperature', 'hour_bef_precipitation',
#        'hour_bef_windspeed', 'hour_bef_humidity', 'hour_bef_visibility',
#        'hour_bef_ozone', 'hour_bef_pm10', 'hour_bef_pm2.5', 'count'],
#       dtype='object')

# %%
plt.plot('hour', 'hour_bef_humidity', 'yo', data = train)

# %%
plt.plot('hour', 'count', 'r+', data = train)
plt.plot('hour', 'hour_bef_visibility', 'c^', data = train)

# %% [markdown]
# ### plt.title(label, fontsize)
# - 그래프 제목 생성
#
# ### plt.xlabel(label, fontsize)
# - x축 이름 설정
#
# ### plt.ylabel(label, fontsize)
# - y축 이름 설정

# %%
plt.title('Plot 1', fontsize = 15)
plt.plot('hour', 'count', 'o', data = train)
plt.xlabel('hour', fontsize = 12)
plt.ylabel('count', fontsize = 12)
plt.axvline(8, color = 'red')
plt.text(3, 200, 'go to work', fontsize = 10)
plt.savefig('plot1.png')

# %% [markdown]
# ### plt.axvline(x, color)
# - 축을 가로지르는 세로 선 생성
#
# ### plt.text(x, y, s, fontsize)
# - 원하는 위치에 텍스트 생성

# %% [markdown]
# ### 상관계수

# %% [markdown]
# - 상관계수: 두 개의 변수가 같이 일어나는 강도를 나타내는 수치
# - -1에서 1사이의 값을 지닙니다.
# - -1이나 1인 수치는 현실 세계에서 관측되기 힘든 수치입니다.
# - 분야별로 기준을 정하는 것에 따라 달라지겠지만, 보통 0.4이상이면 두 개의 변수간에 상관성이 있다고 얘기합니다.

# %% [markdown]
# ![상관계수](https://t1.daumcdn.net/cfile/tistory/99DEE1425C6A9F2008)

# %% [markdown]
# - 상관관계는 인과관계와 다릅니다. 아래의 예시를 확인해 봅시다.

# %% [markdown]
# ![상관성 예시](https://miro.medium.com/max/684/1*JLYI5eCVEN7ZUWXBIrrapw.png)

# %% [markdown]
# - 선글라스 판매량이 증가함에 따라, 아이스크림 판매액도 같이 증가하는 것을 볼 수 있습니다.
# - 하지만 선글라스 판매량이 증가했기 **때문에** 아이스크림 판매액이 증가했다라고 해석하는 것은 타당하지 않습니다.
# - 선글라스 판매량이 증가했다는 것은 여름 때문이라고 볼 수 있으므로, 날씨가 더워짐에 따라 선글라스 판매량과 아이스크림 판매액이 같이 증가했다고 보는 것이 타당할 것입니다.

# %% [markdown]
# ### pd.DataFrame.corr()

# %% [markdown]
# - correlation coefficient 의 줄임말 입니다

# %%
train.corr()
# Out:
#                               id      hour  hour_bef_temperature  \
# id                      1.000000 -0.010901             -0.000029
# hour                   -0.010901  1.000000              0.407306
# hour_bef_temperature   -0.000029  0.407306              1.000000
# hour_bef_precipitation -0.056267  0.021646             -0.097056
# hour_bef_windspeed     -0.003353  0.462797              0.375618
# hour_bef_humidity      -0.017948 -0.329612             -0.496088
# hour_bef_visibility     0.008950  0.176491              0.197417
# hour_bef_ozone          0.055234  0.390188              0.541228
# hour_bef_pm10          -0.025510 -0.035907             -0.003830
# hour_bef_pm2.5          0.003545 -0.061229             -0.078665
# count                  -0.002131  0.626047              0.619404
#
#                         hour_bef_precipitation  hour_bef_windspeed  \
# id                                   -0.056267           -0.003353
# hour                                  0.021646            0.462797
# hour_bef_temperature                 -0.097056            0.375618
# hour_bef_precipitation                1.000000            0.022746
# hour_bef_windspeed                    0.022746            1.000000
# hour_bef_humidity                     0.276481           -0.433012
# hour_bef_visibility                  -0.217155            0.252092
# hour_bef_ozone                       -0.062461            0.520526
# hour_bef_pm10                        -0.051266            0.010176
# hour_bef_pm2.5                        0.004742           -0.199113
# count                                -0.163985            0.459906
#
#                         hour_bef_humidity  hour_bef_visibility  \
# id                              -0.017948             0.008950
# hour                            -0.329612             0.176491
# hour_bef_temperature            -0.496088             0.197417
# hour_bef_precipitation           0.276481            -0.217155
# hour_bef_windspeed              -0.433012             0.252092
# hour_bef_humidity                1.000000            -0.592244
# hour_bef_visibility             -0.592244             1.000000
# hour_bef_ozone                  -0.421047             0.101899
# hour_bef_pm10                   -0.108106            -0.403277
# hour_bef_pm2.5                   0.167736            -0.644989
# count                           -0.471142             0.299094
#
#                         hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5  \
# id                            0.055234      -0.025510        0.003545
# hour                          0.390188      -0.035907       -0.061229
# hour_bef_temperature          0.541228      -0.003830       -0.078665
# hour_bef_precipitation       -0.062461      -0.051266        0.004742
# hour_bef_windspeed            0.520526       0.010176       -0.199113
# hour_bef_humidity            -0.421047      -0.108106        0.167736
# hour_bef_visibility           0.101899      -0.403277       -0.644989
# hour_bef_ozone                1.000000       0.113015        0.017313
# hour_bef_pm10                 0.113015       1.000000        0.489558
# hour_bef_pm2.5                0.017313       0.489558        1.000000
# count                         0.477614      -0.114288       -0.134293
#
#                            count
# id                     -0.002131
# hour                    0.626047
# hour_bef_temperature    0.619404
# hour_bef_precipitation -0.163985
# hour_bef_windspeed      0.459906
# hour_bef_humidity      -0.471142
# hour_bef_visibility     0.299094
# hour_bef_ozone          0.477614
# hour_bef_pm10          -0.114288
# hour_bef_pm2.5         -0.134293
# count                   1.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize = (12, 12))
sns.heatmap(train.corr(), annot = True)

# %% [markdown]
# ### sns.lmplot()

# %%
import seaborn as sns

# %%
sns.lmplot(x = 'hour', y = 'count', data = train)

# %% [markdown]
# ### sns.kdeplot()

# %%
train['count'].plot(kind = 'hist', bins = 30)

# %%
sns.kdeplot(train['count'])

# %% [markdown]
# ### sns.boxplot()

# %%
sns.boxplot(x = 'hour', y = 'hour_bef_humidity', data = train)

# %% [markdown]
# ### sns.pairplot()

# %%
sns.pairplot(train[['hour', 'hour_bef_humidity', 'hour_bef_visibility', 'count', 'hour_bef_ozone']])

# %% [markdown]
# ### sns.jointplot()

# %%
sns.jointplot('hour', 'count', data = train, alpha = 0.1)

# %% [markdown]
# ### sns.violinplot()

# %%
sns.violinplot(x = 'hour', y = 'hour_bef_humidity', data = train)

# %% [markdown]
# ### sns.relplot()

# %%
train[train['hour'] > 12]
# Out:
#         id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 0        3    20                  16.3                     1.0
# 1        6    13                  20.1                     0.0
# 3        8    23                   8.1                     0.0
# 4        9    18                  29.5                     0.0
# 7       16    21                  16.0                     0.0
# ...    ...   ...                   ...                     ...
# 1448  2168    19                  10.6                     0.0
# 1450  2170    15                  23.1                     0.0
# 1453  2173    18                  24.8                     0.0
# 1457  2178    21                  20.7                     0.0
# 1458  2179    17                  21.1                     0.0
#
#       hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 0                    1.5               89.0                576.0
# 1                    1.4               48.0                916.0
# 3                    2.7               54.0                946.0
# 4                    4.8                7.0               2000.0
# 7                    6.0               21.0               1961.0
# ...                  ...                ...                  ...
# 1448                 0.8               84.0               1091.0
# 1450                 4.3               23.0               1798.0
# 1453                 3.6               33.0               1262.0
# 1457                 3.7               37.0               1395.0
# 1458                 3.1               47.0               1973.0
#
#       hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5  count
# 0              0.027           76.0            33.0   49.0
# 1              0.042           73.0            40.0  159.0
# 3              0.040           75.0            64.0   57.0
# 4              0.057           27.0            11.0  431.0
# 7              0.050           90.0            28.0  146.0
# ...              ...            ...             ...    ...
# 1448           0.033           23.0            22.0  114.0
# 1450           0.064           54.0            29.0  266.0
# 1453           0.084          113.0            49.0  303.0
# 1457           0.082           71.0            36.0  216.0
# 1458           0.046           38.0            17.0  170.0
#
# [667 rows x 11 columns]

# %%
sns.relplot(x = 'hour', y = 'hour_bef_humidity', hue = 'hour_bef_precipitation', size = 'count', data = train[train['hour'] > 12])

# %% [markdown]
# ## 3. 데이터 전처리
# ## Data Cleansing & Pre-Processing

# %% [markdown]
# ### pd.Series.isna()
# - 결측치 여부를 확인해줍니다.
# - 결측치면 True, 아니면 False

# %%
train.isna().sum()
# Out:
# id                          0
# hour                        0
# hour_bef_temperature        2
# hour_bef_precipitation      2
# hour_bef_windspeed          9
# hour_bef_humidity           2
# hour_bef_visibility         2
# hour_bef_ozone             76
# hour_bef_pm10              90
# hour_bef_pm2.5            117
# count                       0
# dtype: int64

# %% [markdown]
# ### pd.DataFrame.fillna()
# - 결측치를 채우고자 하는 column과 결측치를 대신하여 넣고자 하는 값을 명시해주어야 합니다.

# %%
train['hour_bef_temperature'] = train['hour_bef_temperature'].fillna(value = train['hour_bef_temperature'].mean())

# %%
train.isna().sum()
# Out:
# id                          0
# hour                        0
# hour_bef_temperature        2
# hour_bef_precipitation      2
# hour_bef_windspeed          9
# hour_bef_humidity           2
# hour_bef_visibility         2
# hour_bef_ozone             76
# hour_bef_pm10              90
# hour_bef_pm2.5            117
# count                       0
# dtype: int64

# %%
train_isna_sum = train.isna().sum()

# %%
train_isna_sum[train_isna_sum != 0].index
# Out:
# Index(['hour_bef_temperature', 'hour_bef_precipitation', 'hour_bef_windspeed',
#        'hour_bef_humidity', 'hour_bef_visibility', 'hour_bef_ozone',
#        'hour_bef_pm10', 'hour_bef_pm2.5'],
#       dtype='object')

# %%
na_columns = train_isna_sum[train_isna_sum != 0].index

# %%
def fill_bicycle_na(df, column) :
    
    df[column] = df[column].fillna(value = df[column].mean())

# %%
fill_bicycle_na(train, 'hour_bef_precipitation')

# %%
for col in na_columns:
    
    fill_bicycle_na(train, col)
    
    print(col, '결측값 대체 완료')
# Out:
# hour_bef_temperature 결측값 대체 완료
# hour_bef_precipitation 결측값 대체 완료
# hour_bef_windspeed 결측값 대체 완료
# hour_bef_humidity 결측값 대체 완료
# hour_bef_visibility 결측값 대체 완료
# hour_bef_ozone 결측값 대체 완료
# hour_bef_pm10 결측값 대체 완료
# hour_bef_pm2.5 결측값 대체 완료

# %%
test_isna_sum = test.isna().sum()

# %%
test_na_columns = test_isna_sum[test_isna_sum != 0].index

# %%
for col in test_na_columns:
    print(col)
# Out:
# hour_bef_temperature
# hour_bef_precipitation
# hour_bef_windspeed
# hour_bef_humidity
# hour_bef_visibility
# hour_bef_ozone
# hour_bef_pm10
# hour_bef_pm2.5

# %%
for col in test_na_columns:
    fill_bicycle_na(test, col)
    print(col, '대체 완료')
# Out:
# hour_bef_temperature 대체 완료
# hour_bef_precipitation 대체 완료
# hour_bef_windspeed 대체 완료
# hour_bef_humidity 대체 완료
# hour_bef_visibility 대체 완료
# hour_bef_ozone 대체 완료
# hour_bef_pm10 대체 완료
# hour_bef_pm2.5 대체 완료

# %%
test.isna().sum()
# Out:
# id                        0
# hour                      0
# hour_bef_temperature      0
# hour_bef_precipitation    0
# hour_bef_windspeed        0
# hour_bef_humidity         0
# hour_bef_visibility       0
# hour_bef_ozone            0
# hour_bef_pm10             0
# hour_bef_pm2.5            0
# dtype: int64

# %% [markdown]
# ## 4. 변수 선택 및 모델 구축
# ## Feature Engineering & Initial Modeling

# %% [markdown]
# ### sklearn.neighbors.KNeighborsRegressor()
# - KNN 모형

# %% [markdown]
# ![](https://res.cloudinary.com/dyd911kmh/image/upload/f_auto,q_auto:best/v1531424125/KNN_final1_ibdm8a.png)

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
from sklearn.model_selection import KFold

# %%
from sklearn.model_selection import cross_val_score

# %%
from sklearn.neighbors import KNeighborsRegressor
model = KNeighborsRegressor(n_jobs = -1)

# %%
column = ['hour', 'hour_bef_temperature']
X_train = train[column]
y_train = train['count']
X_test = test[column]

# %%
model_5 = KNeighborsRegressor(n_jobs = -1, n_neighbors = 5)
model_7 = KNeighborsRegressor(n_jobs = -1, n_neighbors = 7)
model_9 = KNeighborsRegressor(n_jobs = -1, n_neighbors = 9)

# %%
kfold = KFold(n_splits = 5, shuffle = True, random_state = 10)

# %%
np.mean(cross_val_score(model_5, X_train, y_train, cv = kfold, scoring = 'neg_mean_squared_error'))
# Out:
# -2154.4346238290263

# %%
np.mean(cross_val_score(model_7, X_train, y_train, cv = kfold, scoring = 'neg_mean_squared_error'))
# Out:
# -2059.3699019701085

# %%
np.mean(cross_val_score(model_9, X_train, y_train, cv = kfold, scoring = 'neg_mean_squared_error'))
# Out:
# -1993.3584133742238

# %%
model_9.fit(X_train, y_train)
# Out:
# KNeighborsRegressor(n_jobs=-1, n_neighbors=9)

# %%
submission['count'] = model_9.predict(X_test)

# %%
submission.to_csv('knn_9.csv', index = False)

# %%
model.fit(X_train, y_train)
# Out:
# KNeighborsRegressor(n_jobs=-1)

# %%
submission['count'] = model.predict(X_test)

# %%
submission.to_csv('knn_5.csv', index = False)

# %%
train
# Out:
#         id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 0        3    20                  16.3                     1.0
# 1        6    13                  20.1                     0.0
# 2        7     6                  13.9                     0.0
# 3        8    23                   8.1                     0.0
# 4        9    18                  29.5                     0.0
# ...    ...   ...                   ...                     ...
# 1454  2174     4                  16.8                     0.0
# 1455  2175     3                  10.8                     0.0
# 1456  2176     5                  18.3                     0.0
# 1457  2178    21                  20.7                     0.0
# 1458  2179    17                  21.1                     0.0
#
#       hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 0                    1.5               89.0                576.0
# 1                    1.4               48.0                916.0
# 2                    0.7               79.0               1382.0
# 3                    2.7               54.0                946.0
# 4                    4.8                7.0               2000.0
# ...                  ...                ...                  ...
# 1454                 1.6               53.0               2000.0
# 1455                 3.8               45.0               2000.0
# 1456                 1.9               54.0               2000.0
# 1457                 3.7               37.0               1395.0
# 1458                 3.1               47.0               1973.0
#
#       hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5  count
# 0              0.027           76.0            33.0   49.0
# 1              0.042           73.0            40.0  159.0
# 2              0.033           32.0            19.0   26.0
# 3              0.040           75.0            64.0   57.0
# 4              0.057           27.0            11.0  431.0
# ...              ...            ...             ...    ...
# 1454           0.031           37.0            27.0   21.0
# 1455           0.039           34.0            19.0   20.0
# 1456           0.009           30.0            21.0   22.0
# 1457           0.082           71.0            36.0  216.0
# 1458           0.046           38.0            17.0  170.0
#
# [1459 rows x 11 columns]

# %% [markdown]
# ### sklearn.ensemble.RandomForestRegressor()
# - 랜덤 포레스트 모형

# %% [markdown]
# ![](https://cdn.analyticsvidhya.com/wp-content/uploads/2020/02/rfc_vs_dt1.png)

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()

# %%
train
# Out:
#         id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 0        3    20                  16.3                     1.0
# 1        6    13                  20.1                     0.0
# 2        7     6                  13.9                     0.0
# 3        8    23                   8.1                     0.0
# 4        9    18                  29.5                     0.0
# ...    ...   ...                   ...                     ...
# 1454  2174     4                  16.8                     0.0
# 1455  2175     3                  10.8                     0.0
# 1456  2176     5                  18.3                     0.0
# 1457  2178    21                  20.7                     0.0
# 1458  2179    17                  21.1                     0.0
#
#       hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 0                    1.5               89.0                576.0
# 1                    1.4               48.0                916.0
# 2                    0.7               79.0               1382.0
# 3                    2.7               54.0                946.0
# 4                    4.8                7.0               2000.0
# ...                  ...                ...                  ...
# 1454                 1.6               53.0               2000.0
# 1455                 3.8               45.0               2000.0
# 1456                 1.9               54.0               2000.0
# 1457                 3.7               37.0               1395.0
# 1458                 3.1               47.0               1973.0
#
#       hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5  count
# 0              0.027           76.0            33.0   49.0
# 1              0.042           73.0            40.0  159.0
# 2              0.033           32.0            19.0   26.0
# 3              0.040           75.0            64.0   57.0
# 4              0.057           27.0            11.0  431.0
# ...              ...            ...             ...    ...
# 1454           0.031           37.0            27.0   21.0
# 1455           0.039           34.0            19.0   20.0
# 1456           0.009           30.0            21.0   22.0
# 1457           0.082           71.0            36.0  216.0
# 1458           0.046           38.0            17.0  170.0
#
# [1459 rows x 11 columns]

# %%
X_train = train.drop(['id', 'count'], axis = 1)
y_train = train['count']
X_test = test.drop('id', axis = 1)

# %%
X_train.shape, y_train.shape, X_test.shape
# Out:
# ((1459, 9), (1459,), (715, 9))

# %%
from sklearn.model_selection import GridSearchCV

# %%
RandomForestRegressor()

# %%
param = {'min_samples_split': [30, 50, 70],
        'max_depth': [5, 6, 7],
        'n_estimators': [50, 150, 250]}

# %%
param
# Out:
# {'min_samples_split': [30, 50, 70], 'max_depth': [5, 6, 7]}

# %%
gs = GridSearchCV(estimator=model, param_grid=param, scoring = 'neg_mean_squared_error', cv = 3)

# %%
gs
# Out:
# GridSearchCV(cv=3, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [5, 6, 7],
#                          'min_samples_split': [30, 50, 70],
#                          'n_estimators': [50, 150, 250]},
#              scoring='neg_mean_squared_error')

# %%
gs.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [5, 6, 7],
#                          'min_samples_split': [30, 50, 70],
#                          'n_estimators': [50, 150, 250]},
#              scoring='neg_mean_squared_error')

# %%
submission['count'] = gs.predict(X_test)

# %%
submission.to_csv('gridsearch.csv', index = False)

# %%
gs.best_params_
# Out:
# {'max_depth': 7, 'min_samples_split': 30, 'n_estimators': 250}

# %%
pd.DataFrame(gs.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.079097      0.009787         0.007856    5.488766e-03
# 1        0.224834      0.008680         0.015623    1.975664e-06
# 2        0.398692      0.011345         0.015402    3.121677e-04
# 3        0.078108      0.000002         0.000000    0.000000e+00
# 4        0.231889      0.009927         0.003325    4.701902e-03
# 5        0.383549      0.003108         0.015068    7.833137e-04
# 6        0.075133      0.000470         0.003989    1.949921e-06
# 7        0.223090      0.005222         0.011855    2.661548e-03
# 8        0.384519      0.000832         0.014964    9.024282e-06
# 9        0.088668      0.000675         0.004977    9.053630e-06
# 10       0.250925      0.001399         0.010416    7.364909e-03
# 11       0.412888      0.006768         0.015622    1.184119e-06
# 12       0.083314      0.007364         0.000000    0.000000e+00
# 13       0.245518      0.002319         0.009639    4.686749e-04
# 14       0.390707      0.000251         0.015622    2.973602e-07
# 15       0.072899      0.007364         0.005207    7.364010e-03
# 16       0.229113      0.007364         0.000000    0.000000e+00
# 17       0.374912      0.000001         0.015621    8.920806e-07
# 18       0.088521      0.007364         0.000000    0.000000e+00
# 19       0.281245      0.022179         0.008531    6.458351e-03
# 20       0.434078      0.003647         0.015736    1.617316e-04
# 21       0.083313      0.007364         0.000000    0.000000e+00
# 22       0.242999      0.006135         0.013904    6.276933e-03
# 23       0.404460      0.001222         0.015403    3.135728e-04
# 24       0.080401      0.003245         0.006538    6.625138e-03
# 25       0.236367      0.003550         0.009641    4.697970e-04
# 26       0.391822      0.002179         0.015623    9.602742e-07
#
#    param_max_depth param_min_samples_split param_n_estimators  \
# 0                5                      30                 50
# 1                5                      30                150
# 2                5                      30                250
# 3                5                      50                 50
# 4                5                      50                150
# 5                5                      50                250
# 6                5                      70                 50
# 7                5                      70                150
# 8                5                      70                250
# 9                6                      30                 50
# 10               6                      30                150
# 11               6                      30                250
# 12               6                      50                 50
# 13               6                      50                150
# 14               6                      50                250
# 15               6                      70                 50
# 16               6                      70                150
# 17               6                      70                250
# 18               7                      30                 50
# 19               7                      30                150
# 20               7                      30                250
# 21               7                      50                 50
# 22               7                      50                150
# 23               7                      50                250
# 24               7                      70                 50
# 25               7                      70                150
# 26               7                      70                250
#
#                                                params  split0_test_score  \
# 0   {'max_depth': 5, 'min_samples_split': 30, 'n_e...       -2081.298782
# 1   {'max_depth': 5, 'min_samples_split': 30, 'n_e...       -2106.162301
# 2   {'max_depth': 5, 'min_samples_split': 30, 'n_e...       -2082.069244
# 3   {'max_depth': 5, 'min_samples_split': 50, 'n_e...       -2132.449251
# 4   {'max_depth': 5, 'min_samples_split': 50, 'n_e...       -2139.301612
# 5   {'max_depth': 5, 'min_samples_split': 50, 'n_e...       -2154.276061
# 6   {'max_depth': 5, 'min_samples_split': 70, 'n_e...       -2311.247159
# 7   {'max_depth': 5, 'min_samples_split': 70, 'n_e...       -2287.931134
# 8   {'max_depth': 5, 'min_samples_split': 70, 'n_e...       -2271.501840
# 9   {'max_depth': 6, 'min_samples_split': 30, 'n_e...       -2030.228992
# 10  {'max_depth': 6, 'min_samples_split': 30, 'n_e...       -2000.683772
# 11  {'max_depth': 6, 'min_samples_split': 30, 'n_e...       -2015.498792
# 12  {'max_depth': 6, 'min_samples_split': 50, 'n_e...       -2129.371515
# 13  {'max_depth': 6, 'min_samples_split': 50, 'n_e...       -2102.627283
# 14  {'max_depth': 6, 'min_samples_split': 50, 'n_e...       -2124.733959
# 15  {'max_depth': 6, 'min_samples_split': 70, 'n_e...       -2230.814735
# 16  {'max_depth': 6, 'min_samples_split': 70, 'n_e...       -2281.034660
# 17  {'max_depth': 6, 'min_samples_split': 70, 'n_e...       -2271.712523
# 18  {'max_depth': 7, 'min_samples_split': 30, 'n_e...       -1970.644551
# 19  {'max_depth': 7, 'min_samples_split': 30, 'n_e...       -1977.371038
# 20  {'max_depth': 7, 'min_samples_split': 30, 'n_e...       -1960.287681
# 21  {'max_depth': 7, 'min_samples_split': 50, 'n_e...       -2135.295187
# 22  {'max_depth': 7, 'min_samples_split': 50, 'n_e...       -2121.646773
# 23  {'max_depth': 7, 'min_samples_split': 50, 'n_e...       -2119.414737
# 24  {'max_depth': 7, 'min_samples_split': 70, 'n_e...       -2291.214593
# 25  {'max_depth': 7, 'min_samples_split': 70, 'n_e...       -2256.600596
# 26  {'max_depth': 7, 'min_samples_split': 70, 'n_e...       -2248.450286
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0        -1741.717573       -1794.355614     -1872.457323      149.228588
# 1        -1788.461557       -1773.175525     -1889.266461      153.495428
# 2        -1788.679910       -1765.346015     -1878.698390      144.120080
# 3        -1810.156748       -1832.567724     -1925.057908      146.932955
# 4        -1841.952695       -1797.793818     -1926.349375      151.655296
# 5        -1824.327316       -1821.687043     -1933.430140      156.165368
# 6        -1909.176060       -1842.944037     -2021.122419      206.923406
# 7        -1914.746127       -1840.371231     -2014.349497      195.819799
# 8        -1908.830539       -1829.389958     -2003.240779      192.441678
# 9        -1647.251710       -1759.512754     -1812.331152      160.748742
# 10       -1683.000464       -1736.182000     -1806.622079      138.929297
# 11       -1684.496476       -1738.220084     -1812.738451      145.041082
# 12       -1783.790332       -1758.138660     -1890.433502      169.278927
# 13       -1748.676293       -1797.731597     -1883.011724      156.577672
# 14       -1769.842428       -1806.846181     -1900.474189      159.293550
# 15       -1910.636084       -1876.325380     -2005.925400      159.636495
# 16       -1854.198226       -1834.897424     -1990.043437      205.912683
# 17       -1875.936020       -1829.056987     -1992.235177      198.544875
# 18       -1633.454331       -1743.646109     -1782.581664      140.383509
# 19       -1663.400629       -1709.637823     -1783.469830      138.402139
# 20       -1630.553910       -1739.965280     -1776.935624      137.128151
# 21       -1765.615162       -1796.415528     -1899.108626      167.481809
# 22       -1748.110470       -1780.894956     -1883.550733      168.890495
# 23       -1748.459729       -1775.419553     -1881.098006      168.874423
# 24       -1898.814210       -1827.133676     -2005.720827      203.984547
# 25       -1867.712982       -1829.088081     -1984.467220      193.072355
# 26       -1875.205462       -1831.457788     -1985.037845      187.115027
#
#     rank_test_score
# 0                 7
# 1                12
# 2                 8
# 3                16
# 4                17
# 5                18
# 6                27
# 7                26
# 8                23
# 9                 5
# 10                4
# 11                6
# 12               13
# 13               10
# 14               15
# 15               25
# 16               21
# 17               22
# 18                2
# 19                3
# 20                1
# 21               14
# 22               11
# 23                9
# 24               24
# 25               19
# 26               20

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
param = {'min_samples_split': range(30, 70),
        'max_depth': [5, 6, 7],
        'n_estimators': range(50, 250)}

# %%
model = RandomForestRegressor()

# %%
rs = RandomizedSearchCV(estimator=model, param_distributions=param, n_iter = 30, random_state=0, scoring = 'neg_mean_squared_error', n_jobs = -1)

# %%
rs.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(estimator=RandomForestRegressor(), n_iter=30, n_jobs=-1,
#                    param_distributions={'max_depth': [5, 6, 7],
#                                         'min_samples_split': range(30, 70),
#                                         'n_estimators': range(50, 250)},
#                    random_state=0, scoring='neg_mean_squared_error')

# %%
rs.best_params_
# Out:
# {'n_estimators': 171, 'min_samples_split': 34, 'max_depth': 7}

# %%
submission['count'] = rs.predict(X_test)

# %%
submission.to_csv('randomsearch.csv', index = False)

# %%
pd.DataFrame(rs.cv_results_).sort_values('mean_test_score', ascending = False)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 21       0.663026      0.018534         0.024135    4.203040e-03
# 16       0.502057      0.003253         0.017354    1.016859e-03
# 29       0.290821      0.017612         0.007979    1.669095e-03
# 17       0.819807      0.014993         0.025133    3.988743e-04
# 2        0.302191      0.013630         0.010572    4.885388e-04
# 3        0.308375      0.005062         0.010771    3.989459e-04
# 19       0.201261      0.004820         0.007979    2.861023e-07
# 6        0.236567      0.008112         0.009575    1.196766e-03
# 14       0.334904      0.007735         0.011370    4.887723e-04
# 18       0.603585      0.007863         0.020346    7.981897e-04
# 1        0.766548      0.017154         0.023138    7.461363e-04
# 7        0.645273      0.011884         0.020146    7.463529e-04
# 4        0.512229      0.003919         0.016755    3.989220e-04
# 5        0.285237      0.001784         0.010372    4.886750e-04
# 8        0.333109      0.003568         0.011170    3.988267e-04
# 9        0.507443      0.019063         0.016356    4.885778e-04
# 25       0.762361      0.018058         0.024933    8.919634e-04
# 20       0.474331      0.006752         0.017354    4.885193e-04
# 0        0.530369      0.006043         0.018750    2.393651e-03
# 15       0.316154      0.004231         0.010971    6.306756e-04
# 10       0.562695      0.014932         0.019548    1.738888e-03
# 26       0.450395      0.027600         0.014960    4.909339e-07
# 27       0.366818      0.014663         0.012965    6.306757e-04
# 11       0.242950      0.007208         0.009574    4.886555e-04
# 24       0.304783      0.014963         0.011569    4.886556e-04
# 12       0.252724      0.006263         0.009973    6.306757e-04
# 22       0.219612      0.013897         0.008976    6.309019e-04
# 23       0.612561      0.018811         0.021543    1.196726e-03
# 13       0.583240      0.010021         0.020745    7.468500e-04
# 28       0.421472      0.010491         0.009973    6.304495e-04
#
#    param_n_estimators param_min_samples_split param_max_depth  \
# 21                171                      34               7
# 16                139                      35               7
# 29                 80                      42               7
# 17                233                      44               7
# 2                  95                      39               6
# 3                  98                      48               7
# 19                 56                      43               7
# 6                  75                      36               6
# 14                102                      49               7
# 18                177                      41               6
# 1                 249                      43               6
# 7                 207                      53               7
# 4                 173                      55               6
# 5                  93                      56               7
# 8                 108                      61               7
# 9                 166                      60               6
# 25                213                      40               5
# 20                147                      44               5
# 0                 182                      43               5
# 15                100                      63               6
# 10                185                      64               6
# 26                122                      55               5
# 27                101                      54               5
# 11                 80                      67               6
# 24                 86                      60               5
# 12                 82                      69               6
# 22                 66                      61               5
# 23                171                      64               5
# 13                194                      63               5
# 28                127                      69               5
#
#                                                params  split0_test_score  \
# 21  {'n_estimators': 171, 'min_samples_split': 34,...       -1672.709645
# 16  {'n_estimators': 139, 'min_samples_split': 35,...       -1695.880384
# 29  {'n_estimators': 80, 'min_samples_split': 42, ...       -1709.482322
# 17  {'n_estimators': 233, 'min_samples_split': 44,...       -1728.837681
# 2   {'n_estimators': 95, 'min_samples_split': 39, ...       -1726.485248
# 3   {'n_estimators': 98, 'min_samples_split': 48, ...       -1737.031222
# 19  {'n_estimators': 56, 'min_samples_split': 43, ...       -1748.562425
# 6   {'n_estimators': 75, 'min_samples_split': 36, ...       -1724.576186
# 14  {'n_estimators': 102, 'min_samples_split': 49,...       -1747.755439
# 18  {'n_estimators': 177, 'min_samples_split': 41,...       -1741.136404
# 1   {'n_estimators': 249, 'min_samples_split': 43,...       -1726.175770
# 7   {'n_estimators': 207, 'min_samples_split': 53,...       -1766.677722
# 4   {'n_estimators': 173, 'min_samples_split': 55,...       -1793.532378
# 5   {'n_estimators': 93, 'min_samples_split': 56, ...       -1801.027254
# 8   {'n_estimators': 108, 'min_samples_split': 61,...       -1799.786560
# 9   {'n_estimators': 166, 'min_samples_split': 60,...       -1821.030191
# 25  {'n_estimators': 213, 'min_samples_split': 40,...       -1766.254071
# 20  {'n_estimators': 147, 'min_samples_split': 44,...       -1807.130531
# 0   {'n_estimators': 182, 'min_samples_split': 43,...       -1779.423435
# 15  {'n_estimators': 100, 'min_samples_split': 63,...       -1838.177979
# 10  {'n_estimators': 185, 'min_samples_split': 64,...       -1836.653133
# 26  {'n_estimators': 122, 'min_samples_split': 55,...       -1802.715639
# 27  {'n_estimators': 101, 'min_samples_split': 54,...       -1828.575312
# 11  {'n_estimators': 80, 'min_samples_split': 67, ...       -1852.017276
# 24  {'n_estimators': 86, 'min_samples_split': 60, ...       -1824.086708
# 12  {'n_estimators': 82, 'min_samples_split': 69, ...       -1874.162002
# 22  {'n_estimators': 66, 'min_samples_split': 61, ...       -1888.671071
# 23  {'n_estimators': 171, 'min_samples_split': 64,...       -1870.245164
# 13  {'n_estimators': 194, 'min_samples_split': 63,...       -1861.971160
# 28  {'n_estimators': 127, 'min_samples_split': 69,...       -1898.234602
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 21       -1948.602733       -1598.407249       -1801.767210
# 16       -1990.971084       -1562.977708       -1839.429735
# 29       -1984.210969       -1610.736139       -1885.654738
# 17       -2005.061097       -1605.394153       -1845.768137
# 2        -2008.932023       -1660.663971       -1843.033453
# 3        -2010.369703       -1595.730505       -1885.474687
# 19       -2029.417809       -1612.114106       -1861.111137
# 6        -2007.947028       -1648.369018       -1864.456310
# 14       -2016.918133       -1628.170917       -1881.019721
# 18       -2028.800308       -1643.719733       -1875.360409
# 1        -2028.544826       -1648.856969       -1888.440531
# 7        -2036.563992       -1656.721061       -1888.525606
# 4        -2074.839348       -1679.943329       -1941.845907
# 5        -2111.640643       -1678.269557       -1906.287213
# 8        -2098.347020       -1688.362477       -1947.108578
# 9        -2136.964063       -1738.026563       -1951.204668
# 25       -2137.248297       -1774.632239       -1959.997548
# 20       -2148.893419       -1765.343641       -1949.549146
# 0        -2144.046219       -1781.548880       -1963.987258
# 15       -2146.152350       -1759.810993       -1991.535063
# 10       -2176.222751       -1747.028449       -1979.507470
# 26       -2147.218207       -1799.867587       -1987.327441
# 27       -2175.375492       -1790.247197       -1967.452299
# 11       -2174.507436       -1787.569845       -2003.889210
# 24       -2246.730766       -1811.524348       -1999.606134
# 12       -2227.808418       -1803.225519       -2029.179264
# 22       -2154.685949       -1827.751833       -2000.121711
# 23       -2224.626036       -1836.894076       -2009.286910
# 13       -2232.374475       -1843.202471       -2032.449235
# 28       -2264.181406       -1844.814700       -2014.308755
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 21       -1500.507150     -1704.398797      156.796929                1
# 16       -1528.357965     -1723.523375      172.968867                2
# 29       -1487.544613     -1735.525756      180.071321                3
# 17       -1529.521939     -1742.916601      169.673862                4
# 2        -1516.095288     -1751.041997      166.697853                5
# 3        -1548.597047     -1755.440633      173.509761                6
# 19       -1529.417600     -1756.124615      177.709664                7
# 6        -1550.908744     -1759.251457      161.134431                8
# 14       -1549.334974     -1764.639837      168.791972                9
# 18       -1537.387188     -1765.280808      172.543093               10
# 1        -1543.188702     -1767.041360      172.551083               11
# 7        -1573.326644     -1784.363005      164.679547               12
# 4        -1580.813835     -1814.194959      177.283645               13
# 5        -1576.058155     -1814.656564      185.640563               14
# 8        -1597.166321     -1826.154191      179.352253               15
# 9        -1588.091261     -1847.063349      186.826726               16
# 25       -1602.474926     -1848.121416      183.605959               17
# 20       -1573.981365     -1848.979620      192.058783               18
# 0        -1581.737211     -1850.148601      190.309062               19
# 15       -1580.695407     -1863.274358      193.729774               20
# 10       -1588.209686     -1865.524298      200.650889               21
# 26       -1656.560502     -1878.737875      170.432433               22
# 27       -1639.228493     -1880.175758      180.867584               23
# 11       -1597.014417     -1882.999637      195.675948               24
# 24       -1605.323875     -1897.454366      214.725868               25
# 12       -1566.742102     -1900.223461      221.467433               26
# 22       -1668.069135     -1907.859940      163.536213               27
# 23       -1633.724896     -1914.955416      195.947701               28
# 13       -1642.041209     -1922.407710      198.353197               29
# 28       -1625.049359     -1929.317764      209.782421               30

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
submission['count'] = model.predict(X_test)

# %%
submission.to_csv('rf_default.csv', index = False)

# %%
model_100 = RandomForestRegressor(n_estimators=100, n_jobs = -1, random_state=10)
model_200 = RandomForestRegressor(n_estimators=200, n_jobs = -1, random_state=10)
model_300 = RandomForestRegressor(n_estimators=300, n_jobs = -1, random_state=10)
model_500 = RandomForestRegressor(n_estimators=500, n_jobs = -1, random_state=10)

# %%
pd.DataFrame({'n_estimators':[100, 200, 300, 500], 'score':[-1546, -1537, -1529, -1521]}).plot('n_estimators', 'score')

# %%
# %%time
score = cross_val_score(model_100, X_train, y_train, cv = kfold, scoring = 'neg_mean_squared_error')
print(np.mean(score))
# Out:
# -1546.8865621858963
# Wall time: 562 ms

# %%
# %%time
score = cross_val_score(model_200, X_train, y_train, cv = kfold, scoring = 'neg_mean_squared_error')
print(np.mean(score))
# Out:
# -1537.2335820896296
# Wall time: 994 ms

# %%
# %%time
score = cross_val_score(model_300, X_train, y_train, cv = kfold, scoring = 'neg_mean_squared_error')
print(np.mean(score))
# Out:
# -1529.93820386781
# Wall time: 1.42 s

# %%
# %%time
score = cross_val_score(model_500, X_train, y_train, cv = kfold, scoring = 'neg_mean_squared_error')
print(np.mean(score))
# Out:
# -1521.7993785402248
# Wall time: 2.35 s

# %%
model_sam_30 = RandomForestRegressor(n_estimators=500, n_jobs = -1, random_state=10, min_samples_split=30)
model_sam_50 = RandomForestRegressor(n_estimators=500, n_jobs = -1, random_state=10, min_samples_split=50)
model_sam_100 = RandomForestRegressor(n_estimators=500, n_jobs = -1, random_state=10, min_samples_split=100)

# %%
# %%time
score = cross_val_score(model_sam_30, X_train, y_train, cv = kfold, scoring = 'neg_mean_squared_error')
print(np.mean(score))
# Out:
# -1647.5599150463906
# Wall time: 3.07 s

# %%
# %%time
score = cross_val_score(model_sam_50, X_train, y_train, cv = kfold, scoring = 'neg_mean_squared_error')
print(np.mean(score))
# Out:
# -1746.5733867422452
# Wall time: 1.99 s

# %%
# %%time
score = cross_val_score(model_sam_100, X_train, y_train, cv = kfold, scoring = 'neg_mean_squared_error')
print(np.mean(score))
# Out:
# -2009.2340561302196
# Wall time: 1.83 s

# %%
final_model = RandomForestRegressor(n_estimators=500, n_jobs = -1, random_state=10, min_samples_split=30)

# %%
final_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(min_samples_split=30, n_estimators=500, n_jobs=-1,
#                       random_state=10)

# %%
submission['count'] = final_model.predict(X_test)

# %%
submission.to_csv('estimators_500_samples_30.csv', index = False)

# %%
train['hour_bef_temperature'].plot(bins = 30, kind = 'hist')
test['hour_bef_temperature'].plot(bins = 30, kind = 'hist')

# %%
rf_maxf_02 = RandomForestRegressor(n_estimators=500, n_jobs = -1, random_state=10, min_samples_split=30, max_features=0.2)
rf_maxf_04 = RandomForestRegressor(n_estimators=500, n_jobs = -1, random_state=10, min_samples_split=30, max_features=0.4)
rf_maxf_06 = RandomForestRegressor(n_estimators=500, n_jobs = -1, random_state=10, min_samples_split=30, max_features=0.6)
rf_maxf_08 = RandomForestRegressor(n_estimators=500, n_jobs = -1, random_state=10, min_samples_split=30, max_features=0.8)

# %%
# %%time
score = cross_val_score(rf_maxf_02, X_train, y_train, cv = kfold, scoring = 'neg_mean_squared_error')
print(np.mean(score))
# Out:
# -2253.430187736337
# Wall time: 2.94 s

# %%
# %%time
score = cross_val_score(rf_maxf_04, X_train, y_train, cv = kfold, scoring = 'neg_mean_squared_error')
print(np.mean(score))
# Out:
# -1830.923118087825
# Wall time: 1.79 s

# %%
# %%time
score = cross_val_score(rf_maxf_06, X_train, y_train, cv = kfold, scoring = 'neg_mean_squared_error')
print(np.mean(score))
# Out:
# -1714.0867530230257
# Wall time: 1.85 s

# %%
# %%time
score = cross_val_score(rf_maxf_08, X_train, y_train, cv = kfold, scoring = 'neg_mean_squared_error')
print(np.mean(score))
# Out:
# -1673.7873632042495
# Wall time: 2.02 s

# %% [markdown]
# ## 5. 모델 학습 및 검증
# ## Model Tuning & Evaluation

# %% [markdown]
# ### model.fit()
# - 모델 학습

# %% [markdown]
# ### model.predict()
# - 모델 예측

# %% [markdown]
# ### pd.DataFrame.to_csv()
#  - csv파일 저장하는 함수

# %% [markdown]
# ## 교차검증 소개: Cross Validation(CV)

# %% [markdown]
# ### 홀드아웃 교차검증기법(Hold-out Cross Validation)

# %% [markdown]
# ![](https://www.datavedas.com/wp-content/uploads/2018/04/image003.jpg)

# %%
from sklearn.model_selection import train_test_split

# %%
column = ['hour', 'hour_bef_temperature']
X_train = train[column]
y_train = train['count']

# %%
X_train.shape, y_train.shape
# Out:
# ((1459, 2), (1459,))

# %%
1459 * 0.25
# Out:
# 364.75

# %% [markdown]
# > `train_test_split(특징데이터, 타겟데이터, test_size= 0.25, shuffle= True, random_state= 1)`
# - 특징데이터와 타겟데이터를 순서대로 넣어줍니다
# - test_size: 분할할 검증용데이터 사이즈를 설정합니다(0~1)
# - shuffle: 데이터를 섞습니다 <span style='color:red'> <- 순서가 중요한 데이터가 아니라면 언제나 True!</span>
# - random_state: 재구현을 위해 시드값을 넣어줍니다

# %%
X_trn, X_val, y_trn, y_val = train_test_split(X_train, y_train, test_size = 0.25, shuffle = True, random_state = 10)

# %%
X_trn.shape, X_val.shape, y_trn.shape, y_val.shape
# Out:
# ((1094, 2), (365, 2), (1094,), (365,))

# %% [markdown]
# ### K폴드 교차검증기법(K-fold Cross Validation)

# %% [markdown]
# ![](https://www.researchgate.net/profile/Fabian_Pedregosa/publication/278826818/figure/fig10/AS:614336141750297@1523480558954/The-technique-of-KFold-cross-validation-illustrated-here-for-the-case-K-4-involves.png)

# %%
from sklearn.model_selection import KFold

# %% [markdown]
# > `KFold(n_splits= , shuffle= , random_state= 1)`
# - n_splits: 몇 폴드로 데이터를 분할할지 결정합니다
# - shuffle: 데이터를 셔플할지 여부를 결정합니다
# - random_state: 재현을 위해 시드값을 고정합니다

# %% [markdown]
# 이번 검증에는 10개의 분할된 폴드를 활용한 검증을 합니다.
# 다음과 같이 반복문을 이용하여 정확도를 구해봅시다.

# %%
kfolds = KFold(n_splits=10, shuffle = True, random_state=10)

# %% [markdown]
# > ``` for idx_trn, idx_val in kfolds.split(X_trn):
#     train_X, valid_X = X_trn.iloc[idx_trn, :], X_trn.iloc[idx_val, :]
#     train_y, valid_y = y_trn.iloc[idx_trn], y_trn.iloc[idx_val]```
#  - `k폴드.split()`함수를 통해 각 분할로 나누어진 샘플들의 <span style="color:red">인덱스</span>에 접근합니다.

# %%
kfolds = KFold(n_splits=5, shuffle = True, random_state=5)

# %%
import numpy as np

# %%
example = np.array([[0,0],
[1,1],
[2,2],
[3,3],
[4,4],
[10,10],
[11,11],
[12,12],
[13,13],
[14,14]])

# %%
for idx_trn, idx_val in kfolds.split(example):
    print('TRAIN')
    print(example[idx_trn])
    print('VALIDATION')
    print(example[idx_val])
# Out:
# TRAIN
# [[ 0  0]
#  [ 1  1]
#  [ 2  2]
#  [ 3  3]
#  [ 4  4]
#  [11 11]
#  [12 12]
#  [13 13]]
# VALIDATION
# [[10 10]
#  [14 14]]
# TRAIN
# [[ 0  0]
#  [ 1  1]
#  [ 3  3]
#  [10 10]
#  [11 11]
#  [12 12]
#  [13 13]
#  [14 14]]
# VALIDATION
# [[2 2]
#  [4 4]]
# TRAIN
# [[ 0  0]
#  [ 2  2]
#  [ 3  3]
#  [ 4  4]
#  [10 10]
#  [11 11]
#  [13 13]
#  [14 14]]
# VALIDATION
# [[ 1  1]
#  [12 12]]
# TRAIN
# [[ 1  1]
#  [ 2  2]
#  [ 3  3]
#  [ 4  4]
#  [10 10]
#  [11 11]
#  [12 12]
#  [14 14]]
# VALIDATION
# [[ 0  0]
#  [13 13]]
# TRAIN
# [[ 0  0]
#  [ 1  1]
#  [ 2  2]
#  [ 4  4]
#  [10 10]
#  [12 12]
#  [13 13]
#  [14 14]]
# VALIDATION
# [[ 3  3]
#  [11 11]]

# %%
scores = 0
for idx_trn, idx_val in kfolds.split(train_fts):

# %%
from sklearn.model_selection import cross_val_score

# %%
train
# Out:
#         id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 0        3    20                  16.3                     1.0
# 1        6    13                  20.1                     0.0
# 2        7     6                  13.9                     0.0
# 3        8    23                   8.1                     0.0
# 4        9    18                  29.5                     0.0
# ...    ...   ...                   ...                     ...
# 1454  2174     4                  16.8                     0.0
# 1455  2175     3                  10.8                     0.0
# 1456  2176     5                  18.3                     0.0
# 1457  2178    21                  20.7                     0.0
# 1458  2179    17                  21.1                     0.0
#
#       hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 0                    1.5               89.0                576.0
# 1                    1.4               48.0                916.0
# 2                    0.7               79.0               1382.0
# 3                    2.7               54.0                946.0
# 4                    4.8                7.0               2000.0
# ...                  ...                ...                  ...
# 1454                 1.6               53.0               2000.0
# 1455                 3.8               45.0               2000.0
# 1456                 1.9               54.0               2000.0
# 1457                 3.7               37.0               1395.0
# 1458                 3.1               47.0               1973.0
#
#       hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5  count
# 0              0.027           76.0            33.0   49.0
# 1              0.042           73.0            40.0  159.0
# 2              0.033           32.0            19.0   26.0
# 3              0.040           75.0            64.0   57.0
# 4              0.057           27.0            11.0  431.0
# ...              ...            ...             ...    ...
# 1454           0.031           37.0            27.0   21.0
# 1455           0.039           34.0            19.0   20.0
# 1456           0.009           30.0            21.0   22.0
# 1457           0.082           71.0            36.0  216.0
# 1458           0.046           38.0            17.0  170.0
#
# [1459 rows x 11 columns]

# %%
cross_val_score()

# %% [markdown]
# ## 6. 결과 및 결언
# ## Conclusion & Discussion

# %%
# !pip install scholar
# Out:
# Collecting scholar
#   Downloading scholar-1.0.6-py2.py3-none-any.whl (7.6 kB)
# Collecting PTable
#   Downloading PTable-0.9.2.tar.gz (31 kB)
# Requirement already satisfied: requests in c:\users\ict01_00\anaconda3\lib\site-packages (from scholar) (2.24.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\ict01_00\anaconda3\lib\site-packages (from scholar) (4.9.1)
# Requirement already satisfied: future in c:\users\ict01_00\anaconda3\lib\site-packages (from scholar) (0.18.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\ict01_00\anaconda3\lib\site-packages (from requests->scholar) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\ict01_00\anaconda3\lib\site-packages (from requests->scholar) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ict01_00\anaconda3\lib\site-packages (from requests->scholar) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\ict01_00\anaconda3\lib\site-packages (from requests->scholar) (1.25.9)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ict01_00\anaconda3\lib\site-packages (from beautifulsoup4->scholar) (2.0.1)
# Building wheels for collected packages: PTable
#   Building wheel for PTable (setup.py): started
#   Building wheel for PTable (setup.py): finished with status 'done'
#   Created wheel for PTable: filename=PTable-0.9.2-py3-none-any.whl size=22909 sha256=b6f3735786947dde35f877f77b0138e89f9bdb2dc355c5bf8971d418220abf93
#   Stored in directory: c:\users\ict01_00\appdata\local\pip\cache\wheels\1b\3a\02\8d8da2bca2223dda2f827949c88b2d82dc85dccbc2bb6265e5
# Successfully built PTable
# Installing collected packages: PTable, scholar
# Successfully installed PTable-0.9.2 scholar-1.0.6

# %%
# !pip install article
# Out:
# Collecting article
#   Downloading article-0.1.1.tar.gz (724 bytes)
# Building wheels for collected packages: article
#   Building wheel for article (setup.py): started
#   Building wheel for article (setup.py): finished with status 'done'
#   Created wheel for article: filename=article-0.1.1-py3-none-any.whl size=1085 sha256=25289e7e8490c99ff902c7fa1cda9948f5f7cd78ccbeabb6cbed232271f78340
#   Stored in directory: c:\users\ict01_00\appdata\local\pip\cache\wheels\8c\f2\76\01034ed0aabfb2e4918d6da9d0f61fa4decdfa5fac7f63ea7c
# Successfully built article
# Installing collected packages: article
# Successfully installed article-0.1.1

# %%
import article
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-23f729158c8b> in <module>
# ----> 1 import article
#
# ModuleNotFoundError: No module named 'article'

# %%
import scholar
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-dff7dfb5bdc2> in <module>
# ----> 1 import scholar
#
# ~\anaconda3\lib\site-packages\scholar\__init__.py in <module>
# ----> 1 from .scholar import Scholar
#
# ~\anaconda3\lib\site-packages\scholar\scholar.py in <module>
#       1 from bs4 import BeautifulSoup
# ----> 2 from article import Article
#       3
#       4 import requests
#       5 import constants
#
# ModuleNotFoundError: No module named 'article'

# %%
# !pip install newspaper3k
# Out:
# Requirement already satisfied: pip in c:\users\ict01_00\anaconda3\lib\site-packages (20.1.1)
# Collecting install
#   Downloading install-1.3.3-py3-none-any.whl (3.1 kB)
# Collecting newspaper3k
#   Downloading newspaper3k-0.2.8-py3-none-any.whl (211 kB)
# Requirement already satisfied: PyYAML>=3.11 in c:\users\ict01_00\anaconda3\lib\site-packages (from newspaper3k) (5.3.1)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\ict01_00\anaconda3\lib\site-packages (from newspaper3k) (2.8.1)
# Requirement already satisfied: nltk>=3.2.1 in c:\users\ict01_00\anaconda3\lib\site-packages (from newspaper3k) (3.5)
# Requirement already satisfied: requests>=2.10.0 in c:\users\ict01_00\anaconda3\lib\site-packages (from newspaper3k) (2.24.0)
# Collecting feedfinder2>=0.0.4
#   Downloading feedfinder2-0.0.4.tar.gz (3.3 kB)
# Requirement already satisfied: Pillow>=3.3.0 in c:\users\ict01_00\anaconda3\lib\site-packages (from newspaper3k) (7.2.0)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in c:\users\ict01_00\anaconda3\lib\site-packages (from newspaper3k) (4.9.1)
# Collecting tinysegmenter==0.3
#   Downloading tinysegmenter-0.3.tar.gz (16 kB)
# Requirement already satisfied: lxml>=3.6.0 in c:\users\ict01_00\anaconda3\lib\site-packages (from newspaper3k) (4.5.2)
# Collecting feedparser>=5.2.1
#   Downloading feedparser-5.2.1.tar.bz2 (192 kB)
# Collecting tldextract>=2.0.1
#   Downloading tldextract-2.2.2-py2.py3-none-any.whl (48 kB)
# Collecting cssselect>=0.9.2
#   Downloading cssselect-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting jieba3k>=0.35.1
#   Downloading jieba3k-0.35.1.zip (7.4 MB)
# Requirement already satisfied: six>=1.5 in c:\users\ict01_00\anaconda3\lib\site-packages (from python-dateutil>=2.5.3->newspaper3k) (1.15.0)
# Requirement already satisfied: click in c:\users\ict01_00\anaconda3\lib\site-packages (from nltk>=3.2.1->newspaper3k) (7.1.2)
# Requirement already satisfied: joblib in c:\users\ict01_00\anaconda3\lib\site-packages (from nltk>=3.2.1->newspaper3k) (0.16.0)
# Requirement already satisfied: regex in c:\users\ict01_00\anaconda3\lib\site-packages (from nltk>=3.2.1->newspaper3k) (2020.6.8)
# Requirement already satisfied: tqdm in c:\users\ict01_00\anaconda3\lib\site-packages (from nltk>=3.2.1->newspaper3k) (4.47.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\ict01_00\anaconda3\lib\site-packages (from requests>=2.10.0->newspaper3k) (1.25.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\ict01_00\anaconda3\lib\site-packages (from requests>=2.10.0->newspaper3k) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\ict01_00\anaconda3\lib\site-packages (from requests>=2.10.0->newspaper3k) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ict01_00\anaconda3\lib\site-packages (from requests>=2.10.0->newspaper3k) (2020.6.20)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ict01_00\anaconda3\lib\site-packages (from beautifulsoup4>=4.4.1->newspaper3k) (2.0.1)
# Requirement already satisfied: setuptools in c:\users\ict01_00\anaconda3\lib\site-packages (from tldextract>=2.0.1->newspaper3k) (49.2.0.post20200714)
# Collecting requests-file>=1.4
#   Downloading requests_file-1.5.1-py2.py3-none-any.whl (3.7 kB)
# Building wheels for collected packages: feedfinder2, tinysegmenter, feedparser, jieba3k
#   Building wheel for feedfinder2 (setup.py): started
#   Building wheel for feedfinder2 (setup.py): finished with status 'done'
#   Created wheel for feedfinder2: filename=feedfinder2-0.0.4-py3-none-any.whl size=3359 sha256=67a55708474a750a52f499528a3cbcb6be0cd6a2f8e633da66f8d0926c1833fb
#   Stored in directory: c:\users\ict01_00\appdata\local\pip\cache\wheels\b6\09\68\a9f15498ac02c23dde29f18745bc6a6f574ba4ab41861a3575
#   Building wheel for tinysegmenter (setup.py): started
#   Building wheel for tinysegmenter (setup.py): finished with status 'done'
#   Created wheel for tinysegmenter: filename=tinysegmenter-0.3-py3-none-any.whl size=13542 sha256=f60d27e82c08cd4a795c61e03000bb66188bc65178241ecbf1fb7f6fc1669737
#   Stored in directory: c:\users\ict01_00\appdata\local\pip\cache\wheels\99\74\83\8fac1c8d9c648cfabebbbffe97a889f6624817f3aa0bbe6c09
#   Building wheel for feedparser (setup.py): started
#   Building wheel for feedparser (setup.py): finished with status 'done'
#   Created wheel for feedparser: filename=feedparser-5.2.1-py3-none-any.whl size=44944 sha256=fe1f278c0ecb47c64d23d5c972046a46820bdf59a7cb956b2459c0abf76c4928
#   Stored in directory: c:\users\ict01_00\appdata\local\pip\cache\wheels\e8\a3\00\a2395422ba648d592d20ba9b94e7bfcc36c8cf3b5ebdd472fb
#   Building wheel for jieba3k (setup.py): started
#   Building wheel for jieba3k (setup.py): finished with status 'done'
#   Created wheel for jieba3k: filename=jieba3k-0.35.1-py3-none-any.whl size=7398410 sha256=b1b0859382783e5cca02b3387fb369d90c6697d09c61c4e5c03ce57311cdaec6
#   Stored in directory: c:\users\ict01_00\appdata\local\pip\cache\wheels\1f\7e\0c\54f3b0f5164278677899f2db08f2b07943ce2d024a3c862afb
# Successfully built feedfinder2 tinysegmenter feedparser jieba3k
# Installing collected packages: install, feedfinder2, tinysegmenter, feedparser, requests-file, tldextract, cssselect, jieba3k, newspaper3k
# Successfully installed cssselect-1.1.0 feedfinder2-0.0.4 feedparser-5.2.1 install-1.3.3 jieba3k-0.35.1 newspaper3k-0.2.8 requests-file-1.5.1 tinysegmenter-0.3 tldextract-2.2.2
# Collecting newspaper3k
#   Using cached newspaper3k-0.2.8-py3-none-any.whl (211 kB)
# Requirement already satisfied: requests>=2.10.0 in c:\users\ict01_00\anaconda3\lib\site-packages (from newspaper3k) (2.24.0)
# Requirement already satisfied: lxml>=3.6.0 in c:\users\ict01_00\anaconda3\lib\site-packages (from newspaper3k) (4.5.2)
# Collecting tldextract>=2.0.1
#   Using cached tldextract-2.2.2-py2.py3-none-any.whl (48 kB)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\ict01_00\anaconda3\lib\site-packages (from newspaper3k) (2.8.1)
# Requirement already satisfied: Pillow>=3.3.0 in c:\users\ict01_00\anaconda3\lib\site-packages (from newspaper3k) (7.2.0)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in c:\users\ict01_00\anaconda3\lib\site-packages (from newspaper3k) (4.9.1)
# Collecting jieba3k>=0.35.1
#   Using cached jieba3k-0.35.1.zip (7.4 MB)
# Requirement already satisfied: PyYAML>=3.11 in c:\users\ict01_00\anaconda3\lib\site-packages (from newspaper3k) (5.3.1)
# Collecting feedfinder2>=0.0.4
#   Using cached feedfinder2-0.0.4.tar.gz (3.3 kB)
# Collecting cssselect>=0.9.2
#   Using cached cssselect-1.1.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: nltk>=3.2.1 in c:\users\ict01_00\anaconda3\lib\site-packages (from newspaper3k) (3.5)
# Collecting feedparser>=5.2.1
#   Using cached feedparser-5.2.1.tar.bz2 (192 kB)
# Processing c:\users\ict01_00\appdata\local\pip\cache\wheels\99\74\83\8fac1c8d9c648cfabebbbffe97a889f6624817f3aa0bbe6c09\tinysegmenter-0.3-py3-none-any.whl
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ict01_00\anaconda3\lib\site-packages (from requests>=2.10.0->newspaper3k) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\ict01_00\anaconda3\lib\site-packages (from requests>=2.10.0->newspaper3k) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\ict01_00\anaconda3\lib\site-packages (from requests>=2.10.0->newspaper3k) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\ict01_00\anaconda3\lib\site-packages (from requests>=2.10.0->newspaper3k) (1.25.9)
# Collecting requests-file>=1.4
#   Using cached requests_file-1.5.1-py2.py3-none-any.whl (3.7 kB)
# Requirement already satisfied: setuptools in c:\users\ict01_00\anaconda3\lib\site-packages (from tldextract>=2.0.1->newspaper3k) (49.2.0.post20200714)
# Requirement already satisfied: six>=1.5 in c:\users\ict01_00\anaconda3\lib\site-packages (from python-dateutil>=2.5.3->newspaper3k) (1.15.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ict01_00\anaconda3\lib\site-packages (from beautifulsoup4>=4.4.1->newspaper3k) (2.0.1)
# Requirement already satisfied: regex in c:\users\ict01_00\anaconda3\lib\site-packages (from nltk>=3.2.1->newspaper3k) (2020.6.8)
# Requirement already satisfied: click in c:\users\ict01_00\anaconda3\lib\site-packages (from nltk>=3.2.1->newspaper3k) (7.1.2)
# Requirement already satisfied: tqdm in c:\users\ict01_00\anaconda3\lib\site-packages (from nltk>=3.2.1->newspaper3k) (4.47.0)
# Requirement already satisfied: joblib in c:\users\ict01_00\anaconda3\lib\site-packages (from nltk>=3.2.1->newspaper3k) (0.16.0)
# Building wheels for collected packages: jieba3k, feedfinder2, feedparser
#   Building wheel for jieba3k (setup.py): started
#   Building wheel for jieba3k (setup.py): finished with status 'done'
#   Created wheel for jieba3k: filename=jieba3k-0.35.1-py3-none-any.whl size=7398410 sha256=94e2f75f829bc2aa64b853146eeb1c2ea64a905a695559412dc4fce94c955221
#   Stored in directory: c:\users\ict01_00\appdata\local\pip\cache\wheels\1f\7e\0c\54f3b0f5164278677899f2db08f2b07943ce2d024a3c862afb
#   Building wheel for feedfinder2 (setup.py): started
#   Building wheel for feedfinder2 (setup.py): finished with status 'done'
#   Created wheel for feedfinder2: filename=feedfinder2-0.0.4-py3-none-any.whl size=3359 sha256=e9b69886b14ee894bac5c69286abe8efc06d016b6fb44711409c9b2bd9700959
#   Stored in directory: c:\users\ict01_00\appdata\local\pip\cache\wheels\b6\09\68\a9f15498ac02c23dde29f18745bc6a6f574ba4ab41861a3575
#   Building wheel for feedparser (setup.py): started
#   Building wheel for feedparser (setup.py): finished with status 'done'
#   Created wheel for feedparser: filename=feedparser-5.2.1-py3-none-any.whl size=44944 sha256=735a92cf4ca05dbe8f1d01327c0dd7a5a808a7eb14d869e01351722c1594225a
#   Stored in directory: c:\users\ict01_00\appdata\local\pip\cache\wheels\e8\a3\00\a2395422ba648d592d20ba9b94e7bfcc36c8cf3b5ebdd472fb
# Successfully built jieba3k feedfinder2 feedparser
# Installing collected packages: requests-file, tldextract, jieba3k, feedfinder2, cssselect, feedparser, tinysegmenter, newspaper3k
# Successfully installed cssselect-1.1.0 feedfinder2-0.0.4 feedparser-5.2.1 jieba3k-0.35.1 newspaper3k-0.2.8 requests-file-1.5.1 tinysegmenter-0.3 tldextract-2.2.2

# %%
from newspaper import Article

# %%
url = 'https://scholar.google.com/scholar?hl=ko&as_sdt=0%2C5&q=intelligent+tutoring+system&btnG='
article = Article(url)

# %%
article.download()

# %%
article.authors
# Out:
# []

# %%
article.publish_date
# Out:
# ''

# %%
article.text
# Out:
# ''

# %%
# !scholar.py -c 1 --author "albert einstein" --phrase "quantum theory"
# Out:
# Traceback (most recent call last):
#   File "C:\Users\ICT01_00\Desktop\빅데이터 교육\제주TP 2일차\scholar.py", line 1310, in <module>
#     sys.exit(main())
#   File "C:\Users\ICT01_00\Desktop\빅데이터 교육\제주TP 2일차\scholar.py", line 1293, in main
#     querier.send_query(query)
#   File "C:\Users\ICT01_00\Desktop\빅데이터 교육\제주TP 2일차\scholar.py", line 1027, in send_query
#     self.parse(html)
#   File "C:\Users\ICT01_00\Desktop\빅데이터 교육\제주TP 2일차\scholar.py", line 1055, in parse
#     parser.parse(html)
#   File "C:\Users\ICT01_00\Desktop\빅데이터 교육\제주TP 2일차\scholar.py", line 397, in parse
#     self._parse_article(div)
#   File "C:\Users\ICT01_00\Desktop\빅데이터 교육\제주TP 2일차\scholar.py", line 571, in _parse_article
#     if tag.find('div', {'class': 'gs_ttss'}):
# TypeError: slice indices must be integers or None or have an __index__ method
